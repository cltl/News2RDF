# %%
import pickle

# %%
import semeval_classes

# %%
collection = "SignalMedia"
with open('news_items.bin', 'rb') as infile:
    news_items = pickle.load(infile)

# %%
news_item_id='005d3017-7e99-492b-ac40-7b0f56366f2c'
a_news_item = news_items[news_item_id]

# %%
for attr in {'identifier', 'collection',
             'dct', 'publisher'}:
    print(attr, getattr(a_news_item, attr))


for entity_mention_obj in a_news_item.entity_mentions:
    print()
    for attr in ['sentence', 'mention',
                 'the_type', 
                 'begin_index', 'end_index']:
        print(attr, getattr(entity_mention_obj, attr))
# Out:
# dct 2015-09-04T10:43:03Z
# collection SignalMedia
# publisher Pitt Blather
# identifier 005d3017-7e99-492b-ac40-7b0f56366f2c
#
# sentence 25
# mention three quarters
# the_type DATE
# begin_index 3709
# end_index 3723
#
# sentence 16
# mention Wednesday
# the_type DATE
# begin_index 2510
# end_index 2519
#
# sentence 1
# mention the Youngstown State University Penguins
# the_type ORG
# begin_index 122
# end_index 162
#
# sentence 10
# mention Head Coach
# the_type PERSON
# begin_index 1370
# end_index 1380
#
# sentence 23
# mention Conklin ’s
# the_type PERSON
# begin_index 3385
# end_index 3394
#
# sentence 12
# mention Iowa
# the_type GPE
# begin_index 1861
# end_index 1865
#
# sentence 5
# mention Paul Chryst
# the_type PERSON
# begin_index 695
# end_index 706
#
# sentence 24
# mention Pitt
# the_type PERSON
# begin_index 3576
# end_index 3580
#
# sentence 19
# mention Sunday
# the_type DATE
# begin_index 2901
# end_index 2907
#
# sentence 15
# mention I’ll
# the_type ORG
# ...

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF, FOAF, DC, DCTERMS
import datetime

newsItem = URIRef("http://longtailcorpus.org/news/%s" % news_item_id)
g = Graph()

g.add(( newsItem, DCTERMS.source, Literal(news_item_id) ))
g.add(( newsItem, DCTERMS.isPartOf, Literal(collection) ))
x=datetime.datetime.strptime(getattr(a_news_item, 'dct'), '%Y-%m-%dT%H:%M:%SZ') # 2015-09-04T10:43:03Z
g.add(( newsItem, DCTERMS.created, Literal(x)))
g.add(( newsItem, DCTERMS.publisher, Literal(getattr(a_news_item,'publisher'))))

print(g.serialize(format='turtle'))
# Out:
# b'@prefix ns1: <http://purl.org/dc/terms/> .\n@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n@prefix xml: <http://www.w3.org/XML/1998/namespace> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n<http://longtailcorpus.org/news/005d3017-7e99-492b-ac40-7b0f56366f2c> ns1:created "2015-09-04T10:43:03"^^xsd:dateTime ;\n    ns1:isPartOf "SignalMedia" ;\n    ns1:publisher "Pitt Blather" ;\n    ns1:source "005d3017-7e99-492b-ac40-7b0f56366f2c" .\n\n'

# %%
n = Namespace("http://example.org/")

# %%
print(len(g))
